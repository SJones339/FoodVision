# %% [markdown]
# # Quick Start: Training Custom CNN & EfficientNet
#
# This notebook gets you started training both models quickly.
#
# **Models to Train:**
# 1. Custom CNN (from scratch)
# 2. EfficientNet (transfer learning)
#
# **Time Estimate**: 3-4 hours total (mostly waiting for training)
